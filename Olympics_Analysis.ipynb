# %%
import pandas as pd

# %%
df = pd.read_csv('summer.csv')

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %% [markdown]
# ## 1. In how many cities summer Olympics is held so far?

# %%
len(df['City'].unique())
# Out:
# 22

# %%
len(df['Country'].unique())
# Out:
# 148

# %% [markdown]
# ## 2. Which sports is having most of number of  Medals so far?(Top 5)

# %%
(df['Medal'].unique())
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
data = []
for i in df['Sport'].unique():
   data.append([i,len(df[df['Sport']==i])])
data=pd.DataFrame(data, columns = ['Sport', 'Freq'])
d ata=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#          Sport  Freq
# 0     Aquatics  4170
# 1    Athletics  3638
# 17      Rowing  2667
# 4   Gymnastics  2307
# 3      Fencing  1613

# %% [markdown]
# # 3. Which sports is having most of number of Gold Medals so far?(Top 5)

# %%
gold=df[df['Medal']=='Gold']

# %%
gold
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
data = []
for i in gold['Sport'].unique():
    data.append([i,len(gold[gold['Sport']==i])])
data=pd.DataFrame(data, columns = ['Sport', 'Freq'])
data=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#          Sport  Freq
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552

# %% [markdown]
# # 4. Which player has won most of number of Medals(Top 5)

# %%
data = []
for i in df['Athlete'].unique():
    data.append([i,len(df[df['Athlete']==i])])
data=pd.DataFrame(data, columns = ['Athlete', 'Freq'])
data=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#                     Athlete  Freq
# 18640       PHELPS, Michael    22
# 7197       LATYNINA, Larisa    18
# 9948     ANDRIANOV, Nikolay    15
# 6591           ONO, Takashi    13
# 5103   MANGIAROTTI, Edoardo    13

# %% [markdown]
# # 5. Which player has won most of number of Gold  Medals(Top 5)

# %%
data = []
for i in gold['Athlete'].unique():
    data.append([i,len(gold[gold['Athlete']==i])])
data=pd.DataFrame(data, columns = ['Athlete', 'Freq'])
data=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#                Athlete  Freq
# 6851   PHELPS, Michael    18
# 3320       SPITZ, Mark     9
# 2714  LATYNINA, Larisa     9
# 4630       LEWIS, Carl     9
# 907       NURMI, Paavo     9

# %% [markdown]
# ## 6. which year india won first gold medal in summer Olympics

# %%
gold[gold['Country']=='IND']
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %% [markdown]
# # 7. Which sport is having most female Gold medalists(Top 5)

# %%
female=gold[gold['Gender']=='Women']

# %%
female
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
data = []
for i in female['Sport'].unique():
    data.append([i,len(female[female['Sport']==i])])
data=pd.DataFrame(data, columns = ['Sport', 'Freq'])
data=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#          Sport  Freq
# 4     Aquatics   589
# 7    Athletics   389
# 8   Gymnastics   268
# 14      Rowing   217
# 11  Volleyball   166

# %% [markdown]
# ## 8. Which event is most popular in terms on number of players(Top 5)

# %%
data = []
for i in df['Sport'].unique():
   data.append([i,len(df[df['Sport']==i])])
data=pd.DataFrame(data, columns = ['Sport', 'Freq'])
data=data.sort_values(by = 'Freq',ascending = False).head()

# %%
data
# Out:
#          Sport  Freq
# 0     Aquatics  4170
# 1    Athletics  3638
# 17      Rowing  2667
# 4   Gymnastics  2307
# 3      Fencing  1613
